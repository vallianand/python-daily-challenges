# %% [markdown]
# **Coding challenge 1**
#  Introduction to Programming Languages and Python
#  Project Title: Student Profile Creator
# Scenario:
#  You are helping to build a basic student information system for a local school. The school wants to store some basic details about each student and let them update their interests.
# Tasks:
# Create variables to store the student’s name, age, and their favourite subjects they are enrolled in.
# Display the student’s information in a user-friendly format.
# Display the updated list of subjects.

# %%
# Student basic details
student_name = "Sam"
student_age = 23
favourite_subjects = ["Math", "Science", "English"]

# %%
#display student informatiom
print("----- Student Profile -----")
print("Name:", student_name)
print("Age:", student_age)
print("Enrolled Subjects:", favourite_subjects)
# Out:
# ----- Student Profile -----
# Name: Sam
# Age: 23
# Enrolled Subjects: ['Math', 'Science', 'English']

# %%
#update subjects(add a new one)
# Adding a new subject to the list
favourite_subjects.append("Computer Science")  #append to add new subject

print("\n----- Updated Subjects -----")   #/n for new line
print(favourite_subjects)
# Out:
# ----- Updated Subjects -----
# ['Math', 'Science', 'English', 'Computer Science']
